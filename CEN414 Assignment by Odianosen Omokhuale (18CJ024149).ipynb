# %%
#18CJ024149 OMOKHUALE, ODIANOSEN
#CEN414 ASSIGNMENT

print("18CJ024149 OMOKHUALE, ODIANOSEN")

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/Odia/Downloads/Telegram Desktop/Homicides.csv')

df.pivot_table(index='Country', columns = 'Sex', values = '2010').plot(kind = 'bar', figsize=(15,5))

plt.xlabel('Country')
plt.ylabel('2010')
plt.title('Homicides Male and Female Count per 100,000')
plt.legend(loc='upper right')
plt.show()

df = pd.read_csv('C:/Users/Odia/Downloads/Telegram Desktop/Homicide2.csv')

df.pivot_table(index='Country', columns = 'Sex', values = '2011').plot(kind = 'bar', figsize=(15,5))

plt.xlabel('Country')
plt.ylabel('2011')
plt.title('Homicides Male and Female Count per 100,000')
plt.legend(loc='upper right')
plt.show()

df = pd.read_csv('C:/Users/Odia/Downloads/Telegram Desktop/Homicide3.csv')

df.pivot_table(index='Country', columns = 'Sex', values = '2012').plot(kind = 'bar', figsize=(15,5))

plt.xlabel('Country')
plt.ylabel('2012')
plt.title('Homicides Male and Female Count per 100,000')
plt.legend(loc='upper right')
plt.show()

df = pd.read_csv('C:/Users/Odia/Downloads/Telegram Desktop/Homicide4.csv')

df.pivot_table(index='Country', columns = 'Sex', values = '2013').plot(kind = 'bar', figsize=(15,5))

plt.xlabel('Country')
plt.ylabel('2013')
plt.title('Homicides Male and Female Count per 100,000')
plt.legend(loc='upper right')
plt.show()

df = pd.read_csv('C:/Users/Odia/Downloads/Telegram Desktop/Homicide5.csv')

df.pivot_table(index='Country', columns = 'Sex', values = '2014').plot(kind = 'bar', figsize=(15,5))

plt.xlabel('Country')
plt.ylabel('2014')
plt.title('Homicides Male and Female Count per 100,000')
plt.legend(loc='upper right')
plt.show()

df = pd.read_csv('C:/Users/Odia/Downloads/Telegram Desktop/Homicide6.csv')

df.pivot_table(index='Country', columns = 'Sex', values = '2015').plot(kind = 'bar', figsize=(15,5))

plt.xlabel('Country')
plt.ylabel('2015')
plt.title('Homicides Male and Female Count per 100,000')
plt.legend(loc='upper right')
plt.show()

df = pd.read_csv('C:/Users/Odia/Downloads/Telegram Desktop/Homicide7.csv')

df.pivot_table(index='Country', columns = 'Sex', values = '2016').plot(kind = 'bar', figsize=(15,5))

plt.xlabel('Country')
plt.ylabel('2016')
plt.title('Homicides Male and Female Count per 100,000')
plt.legend(loc='upper right')
plt.show()

df = pd.read_csv('C:/Users/Odia/Downloads/Telegram Desktop/Homicide8.csv')

df.pivot_table(index='Country', columns = 'Sex', values = '2017').plot(kind = 'bar', figsize=(15,5))

plt.xlabel('Country')
plt.ylabel('2017')
plt.title('Homicides Male and Female Count per 100,000')
plt.legend(loc='upper right')
plt.show()

df = pd.read_csv('C:/Users/Odia/Downloads/Telegram Desktop/Homicide9.csv')

df.pivot_table(index='Country', columns = 'Sex', values = '2018').plot(kind = 'bar', figsize=(15,5))

plt.xlabel('Country')
plt.ylabel('2018')
plt.title('Homicides Male and Female Count per 100,000')
plt.legend(loc='upper right')
plt.show()

df = pd.read_csv('C:/Users/Odia/Downloads/Telegram Desktop/Homicide10.csv')

df.pivot_table(index='Country', columns = 'Sex', values = '2019').plot(kind = 'bar', figsize=(15,5))

plt.xlabel('Country')
plt.ylabel('2019')
plt.title('Homicides Male and Female Count per 100,000')
plt.legend(loc='upper right')
plt.show()

import math
import sys

def sd_calc(data):
    n = len(data)

    if n <= 1:
        return 0.0

    mean, sd = avg_calc(data), 0.0

    # calculate stan. dev.
    for el in data:
        sd += (float(el) - mean)**2
    sd = math.sqrt(sd / float(n-1))

    return sd

def avg_calc(ls):
    n, mean = len(ls), 0.0

    if n <= 1:
        return ls[0]

    # calculate average
    for el in ls:
        mean = mean + float(el)
    mean = mean / float(n)

    return mean

data = [3444,4432,222,223,43,33,43,34,34,45,65,43,32,33,56,67,23,23,14,2,12,23,2321,24,54,32,21,23,343,456,58,50,34,87,34,35,23,30,23,45,43,56,32,34,123,344,32,23,21,23,43,90,43,45,32,34,32,34,3,5,45,65,43,54,43,32,21,25,22,23,467,500,21,34,21,45,230,301,7865,10980,32,34,25,67,4,6,0,0,34,54,1,8,43,44,6543,9876,2742,10151,456,987,765,876,65,54,43,65,600,2560,550,3338,32,44,43,65,54,65,
]
print("Standard Deviation for 2010: ",sd_calc(data))

import statistics
 
# list of positive integer numbers
data1 = [3444,4432,222,223,43,33,43,34,34,45,65,43,32,33,56,67,23,23,14,2,12,23,2321,24,54,32,21,23,343,456,58,50,34,87,34,35,23,30,23,45,43,56,32,34,123,344,32,23,21,23,43,90,43,45,32,34,32,34,3,5,45,65,43,54,43,32,21,25,22,23,467,500,21,34,21,45,230,301,7865,10980,32,34,25,67,4,6,0,0,34,54,1,8,43,44,6543,9876,2742,10151,456,987,765,876,65,54,43,65,600,2560,550,3338,32,44,43,65,54,65,
]
 
x = statistics.mean(data1)
 
# Printing the mean
print("Mean for 2010 :", x)

import math
import sys

def sd_calc(data):
    n = len(data)

    if n <= 1:
        return 0.0

    mean, sd = avg_calc(data), 0.0

    # calculate stan. dev.
    for el in data:
        sd += (float(el) - mean)**2
    sd = math.sqrt(sd / float(n-1))

    return sd

def avg_calc(ls):
    n, mean = len(ls), 0.0

    if n <= 1:
        return ls[0]

    # calculate average
    for el in ls:
        mean = mean + float(el)
    mean = mean / float(n)

    return mean

data = [3444,4432,222,223,43,33,43,34,34,45,65,43,32,33,56,67,23,23,14,2,12,23,2321,24,54,32,21,23,343,456,58,50,34,87,34,35,23,30,23,45,43,56,32,34,123,344,32,23,21,23,43,90,43,45,32,34,32,34,3,5,45,65,43,54,43,32,21,25,22,23,467,500,21,34,21,45,230,301,7865,10980,32,34,25,67,4,6,0,0,34,54,1,8,43,44,6543,9876,2742,10151,456,987,765,876,65,54,43,65,600,2560,550,3338,32,44,43,65,54,65,]

print("Standard Deviation for 2011: ",sd_calc(data))

import statistics
 
# list of positive integer numbers
data1 = [3444,4432,222,223,43,33,43,34,34,45,65,43,32,33,56,67,23,23,14,2,12,23,2321,24,54,32,21,23,343,456,58,50,34,87,34,35,23,30,23,45,43,56,32,34,123,344,32,23,21,23,43,90,43,45,32,34,32,34,3,5,45,65,43,54,43,32,21,25,22,23,467,500,21,34,21,45,230,301,7865,10980,32,34,25,67,4,6,0,0,34,54,1,8,43,44,6543,9876,2742,10151,456,987,765,876,65,54,43,65,600,2560,550,3338,32,44,43,65,54,65,
]
 
x = statistics.mean(data1)
 
# Printing the mean
print("Mean for 2011 :", x)

import math
import sys

def sd_calc(data):
    n = len(data)

    if n <= 1:
        return 0.0

    mean, sd = avg_calc(data), 0.0

    # calculate stan. dev.
    for el in data:
        sd += (float(el) - mean)**2
    sd = math.sqrt(sd / float(n-1))

    return sd

def avg_calc(ls):
    n, mean = len(ls), 0.0

    if n <= 1:
        return ls[0]

    # calculate average
    for el in ls:
        mean = mean + float(el)
    mean = mean / float(n)

    return mean

data = [2012,5455,5454,455,344,343,334,34,56,34,76,43,67,43,76,43,76,43,67,43,76,43,76,23,44,24,54,43,21,34,34,2334,4344,34,87,34,43,23,30,23,43,55,56,32,34,123,434,32,55,21,23,43,90,43,45,32,34,43,34,54,34,43,43,43,54,34,34,54,25,22,23,565,577,54,34,21,45,230,301,5656,8787,32,34,566,566,4,6,4,6,34,54,1,8,43,44,6543,8787,4545,7677,456,987,765,876,65,54,43,65,600,566,550,666,45,45,65,76,56,56]


print("Standard Deviation for 2012: ",sd_calc(data))

import statistics
 
# list of positive integer numbers
data1 = [2012,5455,5454,455,344,343,334,34,56,34,76,43,67,43,76,43,76,43,67,43,76,43,76,23,44,24,54,43,21,34,34,2334,4344,34,87,34,43,23,30,23,43,55,56,32,34,123,434,32,55,21,23,43,90,43,45,32,34,43,34,54,34,43,43,43,54,34,34,54,25,22,23,565,577,54,34,21,45,230,301,5656,8787,32,34,566,566,4,6,4,6,34,54,1,8,43,44,6543,8787,4545,7677,456,987,765,876,65,54,43,65,600,566,550,666,45,45,65,76,56,56]

 
x = statistics.mean(data1)
 
# Printing the mean
print("Mean for 2012 :", x)

import math
import sys

def sd_calc(data):
    n = len(data)

    if n <= 1:
        return 0.0

    mean, sd = avg_calc(data), 0.0

    # calculate stan. dev.
    for el in data:
        sd += (float(el) - mean)**2
    sd = math.sqrt(sd / float(n-1))

    return sd

def avg_calc(ls):
    n, mean = len(ls), 0.0

    if n <= 1:
        return ls[0]

    # calculate average
    for el in ls:
        mean = mean + float(el)
    mean = mean / float(n)

    return mean

data = [5544,6565,454,456,343,454,45,65,87,87,54,54,67,76,87,63,68,67,87,54,43,36,23,85,24,75,43,75,34,75,4667,7554,34,87,34,43,23,30,77,43,55,56,32,34,355,434,32,66,76,67,76,65,65,45,32,34,466,776,65,35,43,43,75,109,34,34,54,25,22,23,565,876,54,34,21,45,567,987,7675,9877,32,34,566,566,4,6,7,7,34,87,1,8,43,44,6543,8787,4545,7677,456,987,765,876,65,54,43,65,600,566,550,666,45,97,97,76,56,87,]


print("Standard Deviation for 2013: ",sd_calc(data))

import statistics
 
# list of positive integer numbers
data1 = [5544,6565,454,456,343,454,45,65,87,87,54,54,67,76,87,63,68,67,87,54,43,36,23,85,24,75,43,75,34,75,4667,7554,34,87,34,43,23,30,77,43,55,56,32,34,355,434,32,66,76,67,76,65,65,45,32,34,466,776,65,35,43,43,75,109,34,34,54,25,22,23,565,876,54,34,21,45,567,987,7675,9877,32,34,566,566,4,6,7,7,34,87,1,8,43,44,6543,8787,4545,7677,456,987,765,876,65,54,43,65,600,566,550,666,45,97,97,76,56,87,]

 
x = statistics.mean(data1)
 
# Printing the mean
print("Mean for 2013 :", x)

import math
import sys

def sd_calc(data):
    n = len(data)

    if n <= 1:
        return 0.0

    mean, sd = avg_calc(data), 0.0

    # calculate stan. dev.
    for el in data:
        sd += (float(el) - mean)**2
    sd = math.sqrt(sd / float(n-1))

    return sd

def avg_calc(ls):
    n, mean = len(ls), 0.0

    if n <= 1:
        return ls[0]

    # calculate average
    for el in ls:
        mean = mean + float(el)
    mean = mean / float(n)

    return mean

data = [4323,6565,565,767,545,436,45,56,45,35,47,57,83,48,38,38,39,94,38,54,34,36,23,85,46,76,66,75,64,75,5453,5666,44,87,34,43,23,30,43,43,34,56,32,46,355,644,32,46,76,45,64,65,65,45,45,43,433,654,65,54,43,43,54,98,34,34,54,25,22,23,344,856,54,34,21,45,567,987,5466,8676,32,34,566,566,4,6,7,7,46,65,1,6,43,466,543,7665,5666,7677,456,676,786,876,65,54,68,65,76,566,577,876,45,97,97,76,75,57,]


print("Standard Deviation for 2014: ",sd_calc(data))

import statistics
 
# list of positive integer numbers
data1 = [4323,6565,565,767,545,436,45,56,45,35,47,57,83,48,38,38,39,94,38,54,34,36,23,85,46,76,66,75,64,75,5453,5666,44,87,34,43,23,30,43,43,34,56,32,46,355,644,32,46,76,45,64,65,65,45,45,43,433,654,65,54,43,43,54,98,34,34,54,25,22,23,344,856,54,34,21,45,567,987,5466,8676,32,34,566,566,4,6,7,7,46,65,1,6,43,466,543,7665,5666,7677,456,676,786,876,65,54,68,65,76,566,577,876,45,97,97,76,75,57,]
 
x = statistics.mean(data1)
 
# Printing the mean
print("Mean for 2014 :", x)

import math
import sys

def sd_calc(data):
    n = len(data)

    if n <= 1:
        return 0.0

    mean, sd = avg_calc(data), 0.0

    # calculate stan. dev.
    for el in data:
        sd += (float(el) - mean)**2
    sd = math.sqrt(sd / float(n-1))

    return sd

def avg_calc(ls):
    n, mean = len(ls), 0.0

    if n <= 1:
        return ls[0]

    # calculate average
    for el in ls:
        mean = mean + float(el)
    mean = mean / float(n)

    return mean

data = [5643,7654,635,767,124,332,64,36,36,64,4775,46,75,46,36,46,94,38,54,34,46,23,85,46,67,66,74,93,98,3556,6424,35,87,34,43,23,53,43,64,34,53,24,46,355,344,32,42,76,42,64,65,65,75,45,43,466,755,65,54,43,43,54,98,46,34,64,25,64,23,344,466,54,34,21,45,567,586,5678,8554,32,34,566,654,4,6,7,6,46,63,4,6,43,46,3435,8655,6553,5354,456,466,786,754,65,75,68,65,76,566,577,876,65,75,64,64,75,57,]


print("Standard Deviation for 2015: ",sd_calc(data))

import statistics
 
# list of positive integer numbers
data1 = [5643,7654,635,767,124,332,64,36,36,64,4775,46,75,46,36,46,94,38,54,34,46,23,85,46,67,66,74,93,98,3556,6424,35,87,34,43,23,53,43,64,34,53,24,46,355,344,32,42,76,42,64,65,65,75,45,43,466,755,65,54,43,43,54,98,46,34,64,25,64,23,344,466,54,34,21,45,567,586,5678,8554,32,34,566,654,4,6,7,6,46,63,4,6,43,46,3435,8655,6553,5354,456,466,786,754,65,75,68,65,76,566,577,876,65,75,64,64,75,57,]

x = statistics.mean(data1)
 
# Printing the mean
print("Mean for 2015 :", x)

import math
import sys

def sd_calc(data):
    n = len(data)

    if n <= 1:
        return 0.0

    mean, sd = avg_calc(data), 0.0

    # calculate stan. dev.
    for el in data:
        sd += (float(el) - mean)**2
    sd = math.sqrt(sd / float(n-1))

    return sd

def avg_calc(ls):
    n, mean = len(ls), 0.0

    if n <= 1:
        return ls[0]

    # calculate average
    for el in ls:
        mean = mean + float(el)
    mean = mean / float(n)

    return mean

data = [2424,4555,422,746,323,644,64,85,36,64,47,64,64,664,675,46,75,38,47,34,75,75,1,34,46,75,66,74,93,98,3566,7556,35,75,46,75,46,64,75,75,34,75,75,85,343,432,32,53,35,53,64,75,65,75,46,43,466,755,65,54,43,43,54,98,46,34,64,68,35,55,555,566,54,64,21,45,356,646,5678,6466,32,34,566,654,4,6,7,5,35,63,4,6,43,46,3566,5646,3566,6466,456,466,786,756,65,75,68,65,46,66,577,876,65,67,64,64,75,57]


print("Standard Deviation for 2016: ",sd_calc(data))

import statistics
 
# list of positive integer numbers
data1 = [2424,4555,422,746,323,644,64,85,36,64,47,64,64,664,675,46,75,38,47,34,75,75,1,34,46,75,66,74,93,98,3566,7556,35,75,46,75,46,64,75,75,34,75,75,85,343,432,32,53,35,53,64,75,65,75,46,43,466,755,65,54,43,43,54,98,46,34,64,68,35,55,555,566,54,64,21,45,356,646,5678,6466,32,34,566,654,4,6,7,5,35,63,4,6,43,46,3566,5646,3566,6466,456,466,786,756,65,75,68,65,46,66,577,876,65,67,64,64,75,57]

x = statistics.mean(data1)
 
# Printing the mean
print("Mean for 2016 :", x)

import math
import sys

def sd_calc(data):
    n = len(data)

    if n <= 1:
        return 0.0

    mean, sd = avg_calc(data), 0.0

    # calculate stan. dev.
    for el in data:
        sd += (float(el) - mean)**2
    sd = math.sqrt(sd / float(n-1))

    return sd

def avg_calc(ls):
    n, mean = len(ls), 0.0

    if n <= 1:
        return ls[0]

    # calculate average
    for el in ls:
        mean = mean + float(el)
    mean = mean / float(n)

    return mean

data = [3534,5434,345,645,564,543,64,85,34,76,47,64,64,65,45,86,46,97,38,76,34,85,67,134,46,87,66,46,93,87,4556,9456,35,75,45,64,46,74,75,85,34,85,75,86,132,243,32,53,23,54,35,53,35,54,35,43,343,455,65,54,43,45,54,65,46,65,64,65,35,65,465,654,54,65,46,76,564,765,6544,7654,32,34,566,654,4,6,7,5,35,63,4,6,43,46,6532,6433,4564,5775,456,654,786,654,65,75,68,65,46,56,577,876,65,67,64,64,65,57]


print("Standard Deviation for 2017: ",sd_calc(data))

import statistics
 
# list of positive integer numbers
data1 = [3534,5434,345,645,564,543,64,85,34,76,47,64,64,65,45,86,46,97,38,76,34,85,67,134,46,87,66,46,93,87,4556,9456,35,75,45,64,46,74,75,85,34,85,75,86,132,243,32,53,23,54,35,53,35,54,35,43,343,455,65,54,43,45,54,65,46,65,64,65,35,65,465,654,54,65,46,76,564,765,6544,7654,32,34,566,654,4,6,7,5,35,63,4,6,43,46,6532,6433,4564,5775,456,654,786,654,65,75,68,65,46,56,577,876,65,67,64,64,65,57]

x = statistics.mean(data1)
 
# Printing the mean
print("Mean for 2017 :", x)

import math
import sys

def sd_calc(data):
    n = len(data)

    if n <= 1:
        return 0.0

    mean, sd = avg_calc(data), 0.0

    # calculate stan. dev.
    for el in data:
        sd += (float(el) - mean)**2
    sd = math.sqrt(sd / float(n-1))

    return sd

def avg_calc(ls):
    n, mean = len(ls), 0.0

    if n <= 1:
        return ls[0]

    # calculate average
    for el in ls:
        mean = mean + float(el)
    mean = mean / float(n)

    return mean

data = [3553,4633,643,645,564,754,64,75,34,86,47,86,64,76,35,86,46,86,35,76,34,85,75,134,57,75,75,75,93,87,4556,5554,45,64,64,67,46,57,75,75,85,47,75,75,74,7,46,75,47,75,85,85,85,58,85,35,53,532,567,65,54,36,45,54,65,46,65,64,65,35,65,465,643,6464,63,63,564,635,6544,9943,32,34,536,654,3,6,4,6,35,64,6,4,64,76,3366,7543,3646,7543,456,643,643,754,46,64,35,63,64,75,366,764,35,64,46,64,53,57]


print("Standard Deviation for 2018: ",sd_calc(data))

import statistics
 
# list of positive integer numbers
data1 = [3553,4633,643,645,564,754,64,75,34,86,47,86,64,76,35,86,46,86,35,76,34,85,75,134,57,75,75,75,93,87,4556,5554,45,64,64,67,46,57,75,75,85,47,75,75,74,7,46,75,47,75,85,85,85,58,85,35,53,532,567,65,54,36,45,54,65,46,65,64,65,35,65,465,643,6464,63,63,564,635,6544,9943,32,34,536,654,3,6,4,6,35,64,6,4,64,76,3366,7543,3646,7543,456,643,643,754,46,64,35,63,64,75,366,764,35,64,46,64,53,57]

x = statistics.mean(data1)
 
# Printing the mean
print("Mean for 2018 :", x)

import math
import sys

def sd_calc(data):
    n = len(data)

    if n <= 1:
        return 0.0

    mean, sd = avg_calc(data), 0.0

    # calculate stan. dev.
    for el in data:
        sd += (float(el) - mean)**2
    sd = math.sqrt(sd / float(n-1))

    return sd

def avg_calc(ls):
    n, mean = len(ls), 0.0

    if n <= 1:
        return ls[0]

    # calculate average
    for el in ls:
        mean = mean + float(el)
    mean = mean / float(n)

    return mean

data = [5332,5321,244,532,24,53,43,34,34,45,65,43,32,33,56,67,23,23,14,2,12,23,23,21,24,54,32,21,23,34,5732,7844,34,87,34,35,23,30,23,45,43,46,32,76,245,344,46,64,21,23,43,64,43,45,32,34,32,34,3,5,64,64,53,74,43,74,21,75,22,75,467,755,21,34,21,45,230,301,7865,10980,32,34,25,67,4,6,0,0,34,54,1,8,43,44,6543,9876,27,42,101,51,456,987,765,876,65,54,43,65,600,25,60,550,624,32,44,43,65,54,65]


print("Standard Deviation for 2019: ",sd_calc(data))

import statistics
 
# list of positive integer numbers
data1 = [5332,5321,244,532,24,53,43,34,34,45,65,43,32,33,56,67,23,23,14,2,12,23,23,21,24,54,32,21,23,34,5732,7844,34,87,34,35,23,30,23,45,43,46,32,76,245,344,46,64,21,23,43,64,43,45,32,34,32,34,3,5,64,64,53,74,43,74,21,75,22,75,467,755,21,34,21,45,230,301,7865,10980,32,34,25,67,4,6,0,0,34,54,1,8,43,44,6543,9876,27,42,101,51,456,987,765,876,65,54,43,65,600,25,60,550,624,32,44,43,65,54,65]

x = statistics.mean(data1)
 
# Printing the mean
print("Mean for 2019 :", x)


import numpy as np

print("Bar Chart of Standard Deviation")
x = np.array(["2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"])
y = np.array([ 1965.0671208651495, 1965.0671208651495,1747.6153922951619,1983.7387161060578,1717.4463195380376,1825.0955849706,1442.7579753417742,1741.3404001531107,1770.5710279857253,1923.3618235567706])

plt.bar(x,y)
plt.show()

print("Bar Chart of Mean")
a = np.array(["2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"])
b = np.array([ 645.6379310344828, 645.6379310344828,645.4444444444445,750.4568965517242,649.4051724137931,712.0956521739131,575.2241379310345,656.8965517241379,683.0086206896551,598.3025210084033])

plt.bar(a,b)
plt.show()
# Out:
# 18CJ024149 OMOKHUALE, ODIANOSEN
# Standard Deviation for 2010:  1965.0671208651495
# Mean for 2010 : 645.6379310344828
# Standard Deviation for 2011:  1965.0671208651495
# Mean for 2011 : 645.6379310344828
# Standard Deviation for 2012:  1747.6153922951619
# Mean for 2012 : 645.4444444444445
# Standard Deviation for 2013:  1983.7387161060578
# Mean for 2013 : 750.4568965517242
# Standard Deviation for 2014:  1717.4463195380376
# Mean for 2014 : 649.4051724137931
# Standard Deviation for 2015:  1825.0955849706
# Mean for 2015 : 712.0956521739131
# Standard Deviation for 2016:  1442.7579753417742
# Mean for 2016 : 575.2241379310345
# Standard Deviation for 2017:  1741.3404001531107
# Mean for 2017 : 656.8965517241379
# Standard Deviation for 2018:  1770.5710279857253
# Mean for 2018 : 683.0086206896551
# Standard Deviation for 2019:  1923.3618235567706
# Mean for 2019 : 598.3025210084033
# Bar Chart of Standard Deviation
# Bar Chart of Mean
